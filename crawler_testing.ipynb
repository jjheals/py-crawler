# %%
from crawler.Crawler import Crawler
from config.Paths import Paths
from rss_feed.RSS import *

# %%
crawler = Crawler(auto_index_feeds=True, load_storage=True)
# Out:
# Indexing Bleeping Computer (https://www.bleepingcomputer.com/feed/)
# Error fetching the content for "https://www.bleepingcomputer.com/news/legal/tech-support-scam-ring-leader-gets-7-years-in-prison-6m-fine/": 429 Client Error: Too Many Requests for url: https://www.bleepingcomputer.com/news/legal/tech-support-scam-ring-leader-gets-7-years-in-prison-6m-fine/
# Error fetching the content for "https://www.bleepingcomputer.com/news/security/stackexchange-abused-to-spread-malicious-pypi-packages-as-answers/": 429 Client Error: Too Many Requests for url: https://www.bleepingcomputer.com/news/security/stackexchange-abused-to-spread-malicious-pypi-packages-as-answers/
# Error fetching the content for "https://www.bleepingcomputer.com/news/security/hackers-abuse-free-trycloudflare-to-deliver-remote-access-malware/": 429 Client Error: Too Many Requests for url: https://www.bleepingcomputer.com/news/security/hackers-abuse-free-trycloudflare-to-deliver-remote-access-malware/
# ...

# %%
crawler.to_jsons()

# %%
print(f"ARTICLES ({len(crawler.articles)})")
for a in crawler.articles: print(a.to_string())
# Out:
# ARTICLES (979)
# ARTICLE: "Leveraging Wazuh to combat insider threats"
# 	Link: https://www.bleepingcomputer.com/news/security/leveraging-wazuh-to-combat-insider-threats/
# 	Num Terms: 1393
# 	Num Outlinks: 74
# ARTICLE: "Google Drive users angry over losing months of stored data"
# 	Link: https://www.bleepingcomputer.com/news/google/google-drive-users-angry-over-losing-months-of-stored-data/
# 	Num Terms: 1250
# 	Num Outlinks: 69
# ARTICLE: "New Rust-based SysJoker backdoor linked to Hamas hackers"
# 	Link: https://www.bleepingcomputer.com/news/security/new-rust-based-sysjoker-backdoor-linked-to-hamas-hackers/
# 	Num Terms: 1003
# 	Num Outlinks: 73
# ARTICLE: "General Electric investigates claims of cyber attack, data theft"
# 	Link: https://www.bleepingcomputer.com/news/security/general-electric-investigates-claims-of-cyber-attack-data-theft/
# 	Num Terms: 1234
# 	Num Outlinks: 80
# ARTICLE: "Atomic Stealer malware strikes macOS via fake browser updates"
# ...

# %%
print(len(crawler.index))
# Out:
# 24331

# %%
import json
from config.Paths import Paths
articles = json.load(open(Paths.ARTICLES_JSON))
print(len(articles))
# Out:
# 979
